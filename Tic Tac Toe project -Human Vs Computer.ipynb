# %%
 import random
theBoard = {'7': ' ' , '8': ' ' , '9': ' ' ,
            '4': ' ' , '5': ' ' , '6': ' ' ,
            '1': ' ' , '2': ' ' , '3': ' ' }

board_keys = []
computerMove=' '
NewMove=[]
TowMoves=[]
computerTowMoves=[]



for key in theBoard:
    board_keys.append(key)

''' We will have to print the updated board after every move in the game and 
    thus we will make a function in which we'll define the printBoard function
    so that we can easily print the board everytime by calling this function. '''

def printBoard(board):
    print(board['7'] + '|' + board['8'] + '|' + board['9'])
    print('-+-+-')
    print(board['4'] + '|' + board['5'] + '|' + board['6'])
    print('-+-+-')
    print(board['1'] + '|' + board['2'] + '|' + board['3'])



# Now we'll write the main function which has all the gameplay functionality.
def game():
    possibleMoves=[1,2,3,4,5,6,7,8,9]
    turn = 'X'
    count = 0
    computerMoves=0
    
    computerMove=' '
    NewMove=[]
    TowMoves=[]
    computerTowMoves=[]
    theBoard = {'7': ' ' , '8': ' ' , '9': ' ' ,
            '4': ' ' , '5': ' ' , '6': ' ' ,
            '1': ' ' , '2': ' ' , '3': ' ' }

    board_keys = []
    
    for i in range(6):
        
       
                turn='O'
                
                printBoard(theBoard)
                print("All possible moves are: ", possibleMoves )
                print("O moves sequence: ", TowMoves)
                print("X moves sequence: ", computerTowMoves)
                move = input("It's your turn," + turn + " , move to which place? ")

                      
                
                while  int(move) not in possibleMoves:
                    print("That place is not one of possible moves:", possibleMoves,"\n move to which place?")
                    move = input()
                   
               
                
                else:
                    
                    theBoard[move] = turn
                    
                    TowMoves.append(int(move))
                    possibleMoves.remove(int(move))
                   
                    count += 1

            
                turn='X'
                NewMove=possibleMoves
                computerMove=random.choice(NewMove)
                possibleMoves.remove(computerMove)
                theBoard[str(computerMove)] = turn
                computerTowMoves.append(computerMove)
                count += 1

        
                      
                    
        # Now we will check if player X or O has won,for every move after 5 moves. 
                if count >= 5 or possibleMoves ==[]:
                    if theBoard['7'] == theBoard['8'] == theBoard['9'] != ' ': # across the top
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " + theBoard['7'] + " won. ****")                
                        break
                    elif theBoard['4'] == theBoard['5'] == theBoard['6'] != ' ': # across the middle
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " + theBoard['4'] + " won. ****")
                        break
                    elif theBoard['1'] == theBoard['2'] == theBoard['3'] != ' ': # across the bottom
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " + theBoard['1'] + " won. ****")
                        break
                    elif theBoard['1'] == theBoard['4'] == theBoard['7'] != ' ': # down the left side
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " + theBoard['1'] + " won. ****")
                        break
                    elif theBoard['2'] == theBoard['5'] == theBoard['8'] != ' ': # down the middle
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " +theBoard['2'] + " won. ****")
                        break
                    elif theBoard['3'] == theBoard['6'] == theBoard['9'] != ' ': # down the right side
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " +theBoard['3'] + " won. ****")
                        break 
                    elif theBoard['7'] == theBoard['5'] == theBoard['3'] != ' ': # diagonal
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " +theBoard['7'] + " won. ****")
                        break
                    elif theBoard['1'] == theBoard['5'] == theBoard['9'] != ' ': # diagonal
                        printBoard(theBoard)
                        print("\nGame Over.\n")                
                        print(" **** " +theBoard['1'] + " won. ****")
                        break 

                # If neither X nor O wins and the board is full, we'll declare the result as 'tie'.
                    if count == 9:
                        print("\nGame Over.\n")                
                        print("It's a Tie!!")
                        printBoard(theBoard)
                        break

                      
       

    # Now we will ask if player wants to restart the game or not.
    
    restart = input("Do want to play Again?(y/n)")
    if restart == "y" or restart == "Y":  
        
        for key in board_keys:
            theBoard[key] = " "
        

        game()

if __name__ == "__main__":
    game()
# Out:
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# All possible moves are:  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# O moves sequence:  []
# X moves sequence:  []
# It's your turn,O , move to which place? 8
#  |O|
# -+-+-
#  | |
# -+-+-
#  |X|
# All possible moves are:  [1, 3, 4, 5, 6, 7, 9]
# O moves sequence:  [8]
# X moves sequence:  [2]
# It's your turn,O , move to which place? 9
#  |O|O
# -+-+-
#  | |X
# -+-+-
#  |X|
# All possible moves are:  [1, 3, 4, 5, 7]
# O moves sequence:  [8, 9]
# X moves sequence:  [2, 6]
# It's your turn,O , move to which place? 7
# O|O|O
# -+-+-
#  |X|X
# -+-+-
#  |X|
#
# Game Over.
#
#  **** O won. ****
# Do want to play Again?(y/n)y
#  | |
# -+-+-
#  | |
# -+-+-
#  | |
# All possible moves are:  [1, 2, 3, 4, 5, 6, 7, 8, 9]
# O moves sequence:  []
# X moves sequence:  []
# It's your turn,O , move to which place? 5
#  | |
# -+-+-
#  |O|
# -+-+-
#  | |X
# All possible moves are:  [1, 2, 4, 6, 7, 8, 9]
# O moves sequence:  [5]
# X moves sequence:  [3]
# ...
